# %%
from rl_snake.env import SnakeEnv
import rl_snake.visuals as visuals

# %%
env = SnakeEnv()

# %%
obs = env.reset()

# %%
visuals.render_observation(obs)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: >)
